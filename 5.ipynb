# %% [markdown]
# When the goal is to measure how well the model explains the variance in the target variable, the most appropriate evaluation metric is the coefficient of determination, commonly known as
# �
# 2
# R
# 2
#   (R-squared).
#
# The
# �
# 2
# R
# 2
#   score provides a measure of the proportion of the variance in the dependent variable that is predictable from the independent variables. It ranges from 0 to 1, where 0 indicates that the model does not explain any variance, and 1 indicates that the model perfectly explains the variance. A negative
# �
# 2
# R
# 2
#   value can occur if the model performs worse than a simple mean-based prediction.
#
# Mathematically, the
# �
# 2
# R
# 2
#   score is defined as:
#
# �
# 2
# =
# 1
# −
# ∑
# �
# =
# 1
# �
# (
# �
# �
# −
# �
# ^
# �
# )
# 2
# ∑
# �
# =
# 1
# �
# (
# �
# �
# −
# �
# ˉ
# )
# 2
# R
# 2
#  =1−
# ∑
# i=1
# n
# ​
#  (y
# i
# ​
#  −
# y
# ˉ
# ​
#  )
# 2
#
# ∑
# i=1
# n
# ​
#  (y
# i
# ​
#  −
# y
# ^
# ​
#
# i
# ​
#  )
# 2
#
# ​
#
#
# where:
#
# �
# n is the number of data points,
# �
# �
# y
# i
# ​
#   is the true value for the
# �
# i-th data point,
# �
# ^
# �
# y
# ^
# ​
#
# i
# ​
#   is the predicted value for the
# �
# i-th data point,
# �
# ˉ
# y
# ˉ
# ​
#   is the mean of the true values.
# Key points regarding the
# �
# 2
# R
# 2
#   score:
#
# �
# 2
# R
# 2
#   of 1 indicates a perfect fit.
# �
# 2
# R
# 2
#   of 0 indicates that the model does not explain any variance.
# Negative
# �
# 2
# R
# 2
#   values can occur if the model is worse than a simple mean-based prediction.
# When comparing the performance of different SVM regression models with linear, polynomial, and RBF kernels, the
# �
# 2
# R
# 2
#   score is a suitable metric to evaluate how well each model captures the variance in the target variable. Higher
# �
# 2
# R
# 2
#   values indicate better explanatory power of the model in terms of explaining the variability in the target variable.
